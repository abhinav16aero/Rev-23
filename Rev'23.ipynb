# %%
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/brain-dead-placement-data/Placement_Data_Full_Class.csv")

# %%
df.head(60)
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0       1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1       2      M  79.33  Central  78.33   Others   Science     77.48
# 2       3      M  65.00  Central  68.00  Central      Arts     64.00
# 3       4      M  56.00  Central  52.00  Central   Science     52.00
# 4       5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5       6      M  55.00   Others  49.80   Others   Science     67.25
# 6       7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7       8      M  82.00  Central  64.00  Central   Science     66.00
# 8       9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9      10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10     11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11     12      M  69.60  Central  68.40  Central  Commerce     78.30
# 12     13      F  47.00  Central  55.00   Others   Science     65.00
# ...

# %%
df['specialisation'].unique()
# Out:
# array(['Mkt&HR', 'Mkt&Fin'], dtype=object)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df.isnull().count()
# Out:
# sl_no             215
# gender            215
# ssc_p             215
# ssc_b             215
# hsc_p             215
# hsc_b             215
# hsc_s             215
# degree_p          215
# degree_t          215
# workex            215
# etest_p           215
# specialisation    215
# mba_p             215
# status            215
# salary            215
# dtype: int64

# %%
corrM = df.corr()
corrM
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.063764
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.035330
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.076819
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.019272
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.178307
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df['salary'], bins=20)
plt.xlabel('Salary')
plt.ylabel('Count')
plt.title('Salary Distribution')
plt.show()

# %%
plt.scatter(df['status'], df['mba_p'] )
plt.xlabel('status')
plt.ylabel('mba_P')
plt.title(' placement vs mba_p')
plt.show()

# %%
df['specialisation'].replace(['Mkt&HR', 'Mkt&Fin'],
                        [0, 1], inplace=True)

# %%
plt.scatter(df['specialisation'] , df['salary'])
plt.xlabel('specialisation')
plt.ylabel('salary')
plt.title('specialisation vs salary')
plt.show()

# %%
plt.scatter(df['degree_t'] , df['salary'])
plt.xlabel('degree')
plt.ylabel('salary')
plt.title('degree vs salary')
plt.show()

# %%
sns.boxplot(x='workex', y='salary', data=df)
plt.xlabel('Work')
plt.ylabel('Salary')
plt.title('Salary by Gender')
plt.show()

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
to_remove = []
for col in corr_matrix.columns:
    if (corr_matrix[col] < 0.2).all():
        to_remove.append(col)

# %%
df = df.drop(to_remove, axis=1)

# %%
to_remove
# Out:
# []

# %%
from sklearn.preprocessing import OneHotEncoder

# create an instance of the OneHotEncoder class
encoder = OneHotEncoder()

# fit the encoder to the dataset
encoder.fit(df)

# transform the dataset using one-hot encoding
encoded_data = encoder.transform(df)

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p  specialisation  mba_p  status    salary
# ...

# %% [markdown]
# ## Insights
#
# ### Number of workers with salary greater than 500000 is very less.
# ### There not a much difference for MBA % and Placements.
# ### Some workers with 'Mkt&Fin' specialisation have been given more salary.
# ### Also salary of worker with work experience has high salary.
# ### A worker with Coms&Mgmt specialisation has more salary.
